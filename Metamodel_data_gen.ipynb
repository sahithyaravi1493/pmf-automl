# %%
# Imports
import pandas as pd
import json
import zipfile
import ast
import numpy as np
from pandas import HDFStore

# %%
zf = zipfile.ZipFile('all_normalized_accuracy_with_pipelineID.zip') 
df = pd.read_csv(zf.open('all_normalized_accuracy_with_pipelineID.csv'))
df.head()
# Out:
#                  Unnamed: 0        10      1004      1005      1006      1009  \
# 0  --KmMDmpV2AijrwcNUXF1A==  0.822222  1.000000  0.545455  0.866667  0.428571
# 1  -09SOa5WVo1qFl_9BdFzxg==  0.555556  1.000000  0.545455  0.466667  0.428571
# 2  -7wwJDHWcePextSGT4EZsA==  0.466667  0.700000  0.636364  0.600000  0.142857
# 3  -D1QPRAh7YsNlHApr-kHog==       NaN       NaN       NaN       NaN       NaN
# 4  -FyAjiElbrhlbEVSQkqoww==       NaN  0.666667  0.272727  0.333333  0.142857
#
#        1011  1012      1013  1014  ...    979       980       983   987  \
# 0  0.941176   0.3  0.857143  0.55  ...  0.784  0.978648  0.459459  0.84
# 1  0.941176   0.4  0.857143  0.55  ...  0.780  0.975089  0.445946  0.84
# 2  0.764706  -0.1  0.857143  0.55  ...  0.788  0.971530  0.243243  1.00
# 3       NaN   NaN       NaN   NaN  ...    NaN       NaN       NaN   NaN
# 4  0.941176   0.0  0.571429  0.10  ...  0.704  0.886121  0.148649  0.92
#
#         988       991       994   995       996       997
# 0  0.428571  0.953757  0.976471  0.99  0.636364  0.936508
# 1  0.428571  0.942197  0.952941  0.99  0.727273  0.904762
# 2  0.142857  0.410405  0.505882  0.98  0.181818  0.523810
# 3       NaN       NaN       NaN   NaN       NaN       NaN
# 4  0.428571  0.075145  0.294118  0.94 -0.090909  0.523810
#
# [5 rows x 554 columns]

# %%
features = pd.read_csv('data_feats_featurized.csv')
features.head()
# Out:
#    Unnamed: 0  ClassEntropy  ClassProbabilityMax  ClassProbabilityMean  \
# 0          10      1.227678             0.547297                  0.25
# 1        1004      0.650022             0.833333                  0.50
# 2        1005      0.938575             0.644860                  0.50
# 3        1006      0.993536             0.547297                  0.50
# 4        1009      0.969063             0.603175                  0.50
#
#    ClassProbabilityMin  ClassProbabilitySTD  DatasetRatio  \
# 0             0.013514             0.234694      0.121622
# 1             0.166667             0.333333      0.100000
# 2             0.355140             0.144860      0.042056
# 3             0.452703             0.047297      0.121622
# 4             0.396825             0.103175      0.492063
#
#    InverseDatasetRatio  KurtosisMax  KurtosisMean  ...  \
# 0             8.222222    28.713609      9.512438  ...
# 1            10.000000     0.583362     -0.562755  ...
# 2            23.777778    53.392336      9.650634  ...
# 3             8.222222    28.713609      9.512438  ...
# 4             2.032258    43.765030      7.050779  ...
#
#    RatioNumericalToNominal  SkewnessMax  SkewnessMean  SkewnessMin  \
# 0                     0.20     5.387047      2.302843     0.330403
# 1                     0.00     0.931437      0.033920    -0.690259
# 2                     0.00     6.505637      1.640988    -1.144465
# 3                     0.20     5.387047      2.302843     0.330403
# 4                     6.75     6.279502      1.638755    -0.308216
#
#    SkewnessSTD  SymbolsMax  SymbolsMean  SymbolsMin  SymbolsSTD  SymbolsSum
# 0     2.208985         8.0     2.933333         2.0    1.569147        44.0
# 1     0.288005         0.0     0.000000         0.0    0.000000         0.0
# 2     2.165863         0.0     0.000000         0.0    0.000000         0.0
# 3     2.208985         8.0     2.933333         2.0    1.569147        44.0
# 4     1.688892         7.0     4.000000         3.0    1.732051        16.0
#
# [5 rows x 47 columns]

# %%
with open('pipelines.json', 'r') as f:
    pipelines = json.load(f)

# %%
pipeline_dict = dict()
for pipeline in pipelines:
    pipe = dict(pipeline)
    del pipe['id']
    pipeline_dict[pipeline['id']] = pipe

# %%
pipelines =[]
df2 = df
for index,row in df.iterrows():    
    pipelines.append((pipeline_dict[row['Unnamed: 0']]))
df2['pipeline'] = pipelines

# %%
df1 = df.copy()
df1.set_index('Unnamed: 0',inplace=True)
df_changed = df1.stack().reset_index()
df_changed.head()
# Out:
#                  Unnamed: 0 level_1         0
# 0  --KmMDmpV2AijrwcNUXF1A==      10  0.822222
# 1  --KmMDmpV2AijrwcNUXF1A==    1004  1.000000
# 2  --KmMDmpV2AijrwcNUXF1A==    1005  0.545455
# 3  --KmMDmpV2AijrwcNUXF1A==    1006  0.866667
# 4  --KmMDmpV2AijrwcNUXF1A==    1009  0.428571

# %%
df_changed.columns =['pipeline', 'Unnamed: 0', 'accuracy']
df_changed.head()
# Out:
#                    pipeline Unnamed: 0  accuracy
# 0  --KmMDmpV2AijrwcNUXF1A==         10  0.822222
# 1  --KmMDmpV2AijrwcNUXF1A==       1004  1.000000
# 2  --KmMDmpV2AijrwcNUXF1A==       1005  0.545455
# 3  --KmMDmpV2AijrwcNUXF1A==       1006  0.866667
# 4  --KmMDmpV2AijrwcNUXF1A==       1009  0.428571

# %%
df_changed['Unnamed: 0'] = df_changed['Unnamed: 0'].astype(int)

# %%
res = pd.merge(df_changed, features, on='Unnamed: 0', how='left')

# %%
res.shape
# Out:
# (18436846, 49)

# %%
res.to_pickle('df_id.pkl')

# %%
res = pd.read_pickle('df_id.pkl')
pipeline_res=[]
pipeline_ids = np.array(res['pipeline'].values)
pipeline_ids.shape
# Out:
# (18436846,)

# %%
names = np.vectorize(pipeline_dict.get)(pipeline_ids)

# %%
res['pipeline_names'] = names

# %%
res.head()
# Out:
#                    pipeline  Unnamed: 0  accuracy  ClassEntropy  \
# 0  --KmMDmpV2AijrwcNUXF1A==          10  0.822222      1.227678
# 1  --KmMDmpV2AijrwcNUXF1A==        1004  1.000000      0.650022
# 2  --KmMDmpV2AijrwcNUXF1A==        1005  0.545455      0.938575
# 3  --KmMDmpV2AijrwcNUXF1A==        1006  0.866667      0.993536
# 4  --KmMDmpV2AijrwcNUXF1A==        1009  0.428571      0.969063
#
#    ClassProbabilityMax  ClassProbabilityMean  ClassProbabilityMin  \
# 0             0.547297                  0.25             0.013514
# 1             0.833333                  0.50             0.166667
# 2             0.644860                  0.50             0.355140
# 3             0.547297                  0.50             0.452703
# 4             0.603175                  0.50             0.396825
#
#    ClassProbabilitySTD  DatasetRatio  InverseDatasetRatio  ...  SkewnessMax  \
# 0             0.234694      0.121622             8.222222  ...     5.387047
# 1             0.333333      0.100000            10.000000  ...     0.931437
# 2             0.144860      0.042056            23.777778  ...     6.505637
# 3             0.047297      0.121622             8.222222  ...     5.387047
# 4             0.103175      0.492063             2.032258  ...     6.279502
#
#    SkewnessMean  SkewnessMin  SkewnessSTD  SymbolsMax  SymbolsMean  \
# 0      2.302843     0.330403     2.208985         8.0     2.933333
# 1      0.033920    -0.690259     0.288005         0.0     0.000000
# 2      1.640988    -1.144465     2.165863         0.0     0.000000
# 3      2.302843     0.330403     2.208985         8.0     2.933333
# 4      1.638755    -0.308216     1.688892         7.0     4.000000
#
#    SymbolsMin  SymbolsSTD  SymbolsSum  \
# 0         2.0    1.569147        44.0
# 1         0.0    0.000000         0.0
# 2         0.0    0.000000         0.0
# 3         2.0    1.569147        44.0
# 4         3.0    1.732051        16.0
#
#                                       pipeline_names
# 0  {'polynomial_include_bias': 1, 'polynomial_int...
# 1  {'polynomial_include_bias': 1, 'polynomial_int...
# 2  {'polynomial_include_bias': 1, 'polynomial_int...
# 3  {'polynomial_include_bias': 1, 'polynomial_int...
# 4  {'polynomial_include_bias': 1, 'polynomial_int...
#
# [5 rows x 50 columns]

# %%
import pandas as pd
from pandas.io.json import json_normalize

df_2 = json_normalize(res['pipeline_names'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-5c278268af70> in <module>
#       2 from pandas.io.json import json_normalize
#       3
# ----> 4 df_2 = json_normalize(res['pipeline_names'])
#
# ~\anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     209             #       reasonably
#     210             data = nested_to_record(data, sep=sep)
# --> 211         return DataFrame(data)
#     212     elif not isinstance(record_path, list):
#     213         record_path = [record_path]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     446
#     447                     mgr = arrays_to_mgr(arrays, columns, index, columns,
# --> 448                                         dtype=dtype)
#     449                 else:
#     450                     mgr = init_ndarray(data, index, columns, dtype=dtype,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      59     axes = [ensure_index(columns), index]
#      60
# ---> 61     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1664
#    1665     try:
# -> 1666         blocks = form_blocks(arrays, names, axes)
#    1667         mgr = BlockManager(blocks, axes)
#    1668         mgr._consolidate_inplace()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in form_blocks(arrays, names, axes)
#    1720     blocks = []
#    1721     if len(items_dict['FloatBlock']):
# -> 1722         float_blocks = _multi_blockify(items_dict['FloatBlock'])
#    1723         blocks.extend(float_blocks)
#    1724
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _multi_blockify(tuples, dtype)
#    1817     for dtype, tup_block in grouper:
#    1818
# -> 1819         values, placement = _stack_arrays(list(tup_block), dtype)
#    1820
#    1821         block = make_block(values, placement=placement)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1859     shape = (len(arrays),) + _shape_compat(first)
#    1860
# -> 1861     stacked = np.empty(shape, dtype=dtype)
#    1862     for i, arr in enumerate(arrays):
#    1863         stacked[i] = _asarray_compat(arr)
#
# MemoryError:

# %%
result = pd.concat([res, df_2], axis=1).drop('pipeline_names', axis=1)

# %%
result.head()
# Out:
#                    pipeline  Unnamed: 0  accuracy  ClassEntropy  \
# 0  --KmMDmpV2AijrwcNUXF1A==          10  0.822222      1.227678
# 1  --KmMDmpV2AijrwcNUXF1A==        1004  1.000000      0.650022
# 2  --KmMDmpV2AijrwcNUXF1A==        1005  0.545455      0.938575
# 3  --KmMDmpV2AijrwcNUXF1A==        1006  0.866667      0.993536
# 4  --KmMDmpV2AijrwcNUXF1A==        1009  0.428571      0.969063
#
#    ClassProbabilityMax  ClassProbabilityMean  ClassProbabilityMin  \
# 0             0.547297                  0.25             0.013514
# 1             0.833333                  0.50             0.166667
# 2             0.644860                  0.50             0.355140
# 3             0.547297                  0.50             0.452703
# 4             0.603175                  0.50             0.396825
#
#    ClassProbabilitySTD  DatasetRatio  InverseDatasetRatio  ...  \
# 0             0.234694      0.121622             8.222222  ...
# 1             0.333333      0.100000            10.000000  ...
# 2             0.144860      0.042056            23.777778  ...
# 3             0.047297      0.121622             8.222222  ...
# 4             0.103175      0.492063             2.032258  ...
#
#    xgradient_boosting_gamma  xgradient_boosting_learning_rate  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2                       NaN                               NaN
# 3                       NaN                               NaN
# 4                       NaN                               NaN
#
#    xgradient_boosting_max_delta_step  xgradient_boosting_max_depth  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    xgradient_boosting_min_child_weight  xgradient_boosting_n_estimators  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#    xgradient_boosting_reg_alpha  xgradient_boosting_reg_lambda  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    xgradient_boosting_scale_pos_weight  xgradient_boosting_subsample
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
#
# [5 rows x 116 columns]

# %%
result.shape
# Out:
# (18436846, 116)

# %%
store = HDFStore('store.h5')

store['df'] = result  # save it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dba628899ccd> in <module>
# ----> 1 store = HDFStore('store.h5')
#       2
#       3 store['df'] = result  # save it
#
# NameError: name 'HDFStore' is not defined
